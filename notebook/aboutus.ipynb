# %%
with open(r'C:\Users\ADMIN\Desktop\scrapping\aboutus.html','r',encoding='utf-8') as f:
    html = f.read()
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(html)

# %%
soup
# Out:
# <html lang="en"><head>
# <!-- Google Tag Manager -->
# <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-K86J328"></script><script>(function (w, d, s, l, i) {
#       w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#           new Date().getTime(), event: 'gtm.js'
#       }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#           'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#     })(window, document, 'script', 'dataLayer', 'GTM-K86J328');</script>
# <!-- End Google Tag Manager -->
# <!-- Google tag (gtag.js) -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-TNLX524ZM1"></script>
# <script>window.dataLayer = window.dataLayer || []; function gtag() { dataLayer.push(arguments); } gtag('js', new Date()); gtag('config', 'G-TNLX524ZM1'); </script>
# <meta charset="utf-8"/>
# ...

# %%
team = soup.find_all('div',{'class':'board-semhead font-weight-bold'})
Team = []
for i in team:
    Team.append(i.text.strip())

# %%
Team
# Out:
# ['Board Members', 'Advisory Team', 'Advisory Team', 'DISCLAIMER']

# %%
Name = []
name = soup.find_all('div',{'class':'board-head font-weight-light mb-0'})
for i in name:
    Name.append(i.text.strip())

# %%
Name
# Out:
# ['S. Pulla Reddy', 'Jeyaram', 'Phani Karnati']

# %%
pos = soup.find_all('small',{'class':'member-designation-popup font-weight-light mt-0'})
Position = []
for i in pos:
    Position.append(i.text.strip())
Position
# Out:
# ['Founder and Managing Director',
#  'Board Advisor',
#  'Associate Vice President (Technology)']

# %%
des = soup.find_all('p',{'class':'member-designation-content'})
res1 = []
res2 = []
res3 = []
Description = []
for i in des[0:3]:
    res1.append(i.text.strip())
for j in des[3:6]:
    res2.append(j.text.strip())
for k in des[6:11]:
    res3.append(i.text.strip())
Description = [''.join(res1),''.join(res2),''.join(res3)]

# %%
Description
# Out:
# ['Mr. Pulla Reddy has over 36 years of experience in leading enterprise Software & IT Services Industry. He is an Engineering graduate in Computer Science from Nagarjuna University (1985-1989 batch). He started his career with Binary Semantics and Embee Software, New Delhi. Then, he moved to Hyderabad in 1995 and started SP Software.Mr. Pulla Reddy was awarded the Bharat Nirman Excellence Award. Recently, he received the Rashtriya Rattan Award for his role in the Socio-Economic Development of the company.He has a deep understanding of the organization and IT Industry. He is an expert in overseeing global delivery with strategic direction, nurturing customer relationships and spearheading the strategic use of human resources for competitive advantage.',
# ...
